# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#cities
# Out:
# 741

# %%
#cities_df = pd.DataFrame()
#cities_df["City"] = cities
#cities_df["Country"] = ""
#cities_df["Lat"] = ""
#cities_df["Long"] = ""
#cities_df["Max Temp"] = ""
#cities_df["Humidity"] = ""
#cities_df["Cloudiness"] = ""
#cities_df["Wind Speed"] = ""
#cities_df["Current Description"] = ""
#cities_df.head()

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
import requests
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
city_weather = city_weather.json()
city_weather
# Out:
# City Weather found.
# {'coord': {'lon': -6.8166, 'lat': 34.0389},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 71.96,
#   'feels_like': 72.75,
#   'temp_min': 70.63,
#   'temp_max': 72.28,
#   'pressure': 1015,
#   'humidity': 83},
#  'visibility': 8000,
#  'wind': {'speed': 5.75, 'deg': 20},
#  'clouds': {'all': 75},
#  'dt': 1627266169,
#  'sys': {'type': 1,
#   'id': 2402,
#   'country': 'MA',
#   'sunrise': 1627277656,
#   'sunset': 1627327982},
#  'timezone': 3600,
#  'id': 2537763,
#  'name': 'Salé',
#  'cod': 200}

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | cape town
# Processing Record 2 of Set 15 | hilo
# Processing Record 3 of Set 15 | pine bluff
# Processing Record 4 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 5 of Set 15 | rikitea
# Processing Record 6 of Set 15 | lesozavodsk
# Processing Record 7 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 15 | lemoore
# Processing Record 10 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 15 | agadir
# Processing Record 12 of Set 15 | san luis de la paz
# Processing Record 13 of Set 15 | bluff
# Processing Record 14 of Set 15 | khatanga
# Processing Record 15 of Set 15 | hambantota
# Processing Record 16 of Set 15 | aksu
# Processing Record 17 of Set 15 | nikolskoye
# Processing Record 18 of Set 15 | san cristobal
# Processing Record 19 of Set 15 | upernavik
# ...

# %%
#cities

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(15)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Cape Town      ZA -33.9258   18.4232     57.61        15
# 1                 Hilo      US  19.7297 -155.0900     75.61        94
# 2           Pine Bluff      US  34.2284  -92.0032     84.13        70
# 3              Rikitea      PF -23.1203 -134.9692     71.51        73
# 4          Lesozavodsk      RU  45.4794  133.4244     90.30        43
# 5              Lemoore      US  36.3008 -119.7829    100.38        19
# 6               Agadir      MA  30.4202   -9.5982     64.85        79
# 7   San Luis De La Paz      MX  21.3000 -100.5167     68.70        77
# 8                Bluff      NZ -46.6000  168.3333     49.80        84
# 9             Khatanga      RU  71.9667  102.5000     59.74        59
# 10          Hambantota      LK   6.1241   81.1185     81.34        76
# 11                Aksu      CN  41.1231   80.2644     89.60        17
# ...

# %%
 #cities_df.loc[i, "Country"] = city_weather["sys"]["country"]
    #cities_df.loc[i, "Lat"] = city_weather["coord"]["lat"]
    #cities_df.loc[i, "Long"] = city_weather["coord"]["lon"]
    #cities_df.loc[i, "Max Temp"] = city_weather["main"]["temp_max"]
    #cities_df.loc[i, "Humidity"] = city_weather["main"]["humidity"]
    #cities_df.loc[i, "Cloudiness"] = city_weather["clouds"]["all"]
    #cities_df.loc[i, "Wind Speed"] = city_weather["wind"]["speed"]
    #cities_df.loc[i, "Current Description"] = city_weather["weather"][0]["description"]
#cities_df.head(15)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
